# %% [markdown]
# # **Step 1: Libraries**

# %%
from tqdm import tqdm

# Data Science Core
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# EDA
from sklearn.preprocessing import LabelEncoder

# Model
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV 
from sklearn.tree import DecisionTreeClassifier

# Tuning
from sklearn.model_selection import KFold

# Evaluation
from sklearn.metrics import accuracy_score

pd.set_option('display.max_columns', None)
sns.set_theme()

import warnings
from sklearn.exceptions import FitFailedWarning
warnings.filterwarnings("ignore", category=FitFailedWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # **Step 2: Loading data from train and test datasets**

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
fullset = pd.concat([df_train, df_test], axis=0)

# %%
print(df_train.shape)
print(df_test.shape)
print(fullset.shape)
# Out:
# (891, 12)
# (418, 11)
# (1309, 12)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# - Data EDA
# Delete irrelevant data
# Incomplete data
# Graphs

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.describe(include=['O'])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
# plt.figure(figsize=(8, 6))
# sns.barplot(x='Pclass', y='Survived', data=df_train, palette='pink')


# plt.title('Survival Rate by Passenger Class')
# plt.xlabel('Passenger Class')
# plt.ylabel('Survival Rate')

# plt.show()

# %%
# plt.figure()
# sns.barplot(x = 'Sex', y = 'Survived', data = df_train, palette = 'pink')

# plt.title('Survival rate by gender')
# plt.xlabel('Gender')
# plt.ylabel('Survival Rate')

# plt.show()

# %%
#plt.scatter(x = 'Fare', y = 'Survived', data = df_train)

# %%
df_train.query('Fare > 500')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %% [markdown]
# ### **Binning(Continous -> Discrete)**

# %%
# Bin by Age
df_train['Age'].fillna(df_train['Age'].median(), inplace = True)
df_train.loc[df_train['Age'] < 20 ,'Grouped_Age'] = 'T'
df_train.loc[(df_train['Age'] >= 20) & (df_train['Age'] < 50),'Grouped_Age'] = 'M'
df_train.loc[df_train['Age'] >= 50 ,'Grouped_Age'] = 'O'
# Out:
# /var/folders/z_/c14cvny95r120t__g05k8_zh0000gn/T/ipykernel_786/4177145527.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Age'].fillna(df_train['Age'].median(), inplace = True)

# %%
# plt.figure()
# sns.barplot(x = 'Grouped_Age', y = 'Survived', data = df_train, palette = 'pink')

# plt.title('Survival rate by age')
# plt.xlabel('Age')
# plt.ylabel('Survival Rate')

# plt.show()

# %%
df_train['Age'].describe()
# Out:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df_train['Age_bin'] = pd.qcut(df_train['Age'], q=4, labels=False)

# %%
df_train = df_train.drop(['Age'], axis = 1)

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Grouped_Age', 'Age_bin'],
#       dtype='object')

# %% [markdown]
# Feature columns so far we have: Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Grouped_Age
# The Ones We have tested above: Sex, Age, Pclass.
# In the following section, Sibsp, Parch, Fare, Cabin, Embarked will be tested out based on assumptions.

# %%
# SibSp
df_train[["SibSp", "Survived"]].groupby(['SibSp'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
#Parch
df_train[['Parch', 'Survived']].groupby(['Parch'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
#Fare
df_train[['Fare', 'Survived']].groupby(['Fare'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#          Fare  Survived
# 247  512.3292       1.0
# 196   57.9792       1.0
# 89    13.8583       1.0
# 88    13.7917       1.0
# 86    13.4167       1.0
# ..        ...       ...
# 103   15.5500       0.0
# 180   47.1000       0.0
# 179   46.9000       0.0
# 178   42.4000       0.0
# 124   21.0750       0.0
#
# [248 rows x 2 columns]

# %%
# Embarked
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %%
# Cabin
df_train[['Cabin', 'Survived']].groupby(['Cabin'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#        Cabin  Survived
# 73   C62 C64       1.0
# 97       D21       1.0
# 94       D17       1.0
# 95       D19       1.0
# 60      C148       1.0
# ..       ...       ...
# 67       C46       0.0
# 64       C30       0.0
# 59      C128       0.0
# 56      C124       0.0
# 146        T       0.0
#
# [147 rows x 2 columns]

# %% [markdown]
# Higher Survival Rate:
# Pclass: Class 1
# Sex: Female
# Age: T (Younger people)
# SibSp: Less Siblings
# Parch: 3
# Fare: Unknown
# Cabin: Unknown
# Embarked: C

# %%
df_train.info()
# Columns contain null values: Age, Cabin, Embarked
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Grouped_Age  891 non-null    object
#  12  Age_bin      891 non-null    int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 90.6+ KB

# %%
df_train['Embarked'].fillna(df_train['Embarked'].mode()[0], inplace = True)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     891 non-null    object
#  11  Grouped_Age  891 non-null    object
#  12  Age_bin      891 non-null    int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 90.6+ KB
# /var/folders/z_/c14cvny95r120t__g05k8_zh0000gn/T/ipykernel_786/130043138.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Embarked'].fillna(df_train['Embarked'].mode()[0], inplace = True)

# %%
df_train = df_train.drop(['Cabin', 'Fare', 'Ticket', 'Grouped_Age'], axis = 'columns')

# %% [markdown]
# Extraxct people's title

# %%
df_train['Title'] = df_train['Name'].str.extract(r',\s*(\w+)\.\s*', expand=True)

# %%
df_train['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Mlle          2
# Col           2
# Don           1
# Mme           1
# Ms            1
# Lady          1
# Sir           1
# Capt          1
# Jonkheer      1
# Name: count, dtype: int64

# %%
replace_titles = ['Dr', 'Rev', 'Major', 'Mlle', 'Col', 'Don', 'Mme', 'Ms', 'Lady', 'Sir', 'Capt', 'Jonkheer']

# %%
df_train['Title'] = df_train['Title'].replace(replace_titles, ['Uncategorized']*len(replace_titles))

# %%
df_train['Title'].value_counts()
# Out:
# Title
# Mr               517
# Miss             182
# Mrs              125
# Master            40
# Uncategorized     26
# Name: count, dtype: int64

# %%
map_titles = {'Mr': 1, 'Miss': 2, 'Mrs': 3, 'Master': 4, 'Uncategorized': 5}
df_train['Title'] = df_train['Title'].map(map_titles)
df_train['Title'] = df_train['Title'].fillna(5)

# %%
df_train['Title'].value_counts()
# Out:
# Title
# 1.0    517
# 2.0    182
# 3.0    125
# 4.0     40
# 5.0     27
# Name: count, dtype: int64

# %%
df_train = df_train.drop(['Name'], axis = 1)

# %% [markdown]
# Checking for outliers

# %%
df_train.tail()
# Out:
#      PassengerId  Survived  Pclass     Sex  SibSp  Parch Embarked  Age_bin  \
# 886          887         0       2    male      0      0        S        1
# 887          888         1       1  female      0      0        S        0
# 888          889         0       3  female      1      2        S        1
# 889          890         1       1    male      0      0        C        1
# 890          891         0       3    male      0      0        Q        2
#
#      Title
# 886    5.0
# 887    2.0
# 888    2.0
# 889    1.0
# 890    1.0

# %% [markdown]
# Possibly dropping passenger #631

# %%
#df_train.query('Age > 75 & Survived == 1')

# %%
#plt.scatter(x = 'Parch', y = 'Survived', data = df_train)

# %% [markdown]
# Possibily dropping #679

# %%
df_train.query('Parch == 6 & Survived == 0')
# Out:
#      PassengerId  Survived  Pclass     Sex  SibSp  Parch Embarked  Age_bin  \
# 678          679         0       3  female      1      6        S        3
#
#      Title
# 678    3.0

# %%
vals = [679, 631]

# %%
df_train = df_train[df_train.PassengerId.isin(vals) == False]

# %% [markdown]
# # **Step 3: Feature Engineering**

# %% [markdown]
# ### **Encoding**

# %% [markdown]
# * Numerical Value: Age, SibSp, Parch
# * Categorical: Sex, Embarked

# %%
categorical_features_binary = ["Sex"]
categorical_features_onehot = ["Embarked"]

# %%
label_encoder = LabelEncoder()
for feature in categorical_features_binary:
    df_train[feature] = label_encoder.fit_transform(df_train[feature])
df_train
# Out:
#      PassengerId  Survived  Pclass  Sex  SibSp  Parch Embarked  Age_bin  Title
# 0              1         0       3    1      1      0        S        0    1.0
# 1              2         1       1    0      1      0        C        3    3.0
# 2              3         1       3    0      0      0        S        1    2.0
# 3              4         1       1    0      1      0        S        2    3.0
# 4              5         0       3    1      0      0        S        2    1.0
# ..           ...       ...     ...  ...    ...    ...      ...      ...    ...
# 886          887         0       2    1      0      0        S        1    5.0
# 887          888         1       1    0      0      0        S        0    2.0
# 888          889         0       3    0      1      2        S        1    2.0
# 889          890         1       1    1      0      0        C        1    1.0
# 890          891         0       3    1      0      0        Q        2    1.0
#
# [889 rows x 9 columns]

# %%
df_train = pd.get_dummies(df_train, columns=categorical_features_onehot, dtype=int)
df_train
# Out:
#      PassengerId  Survived  Pclass  Sex  SibSp  Parch  Age_bin  Title  \
# 0              1         0       3    1      1      0        0    1.0
# 1              2         1       1    0      1      0        3    3.0
# 2              3         1       3    0      0      0        1    2.0
# 3              4         1       1    0      1      0        2    3.0
# 4              5         0       3    1      0      0        2    1.0
# ..           ...       ...     ...  ...    ...    ...      ...    ...
# 886          887         0       2    1      0      0        1    5.0
# 887          888         1       1    0      0      0        0    2.0
# 888          889         0       3    0      1      2        1    2.0
# 889          890         1       1    1      0      0        1    1.0
# 890          891         0       3    1      0      0        2    1.0
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           0           1
# 1             1           0           0
# 2             0           0           1
# 3             0           0           1
# 4             0           0           1
# ..          ...         ...         ...
# 886           0           0           1
# 887           0           0           1
# 888           0           0           1
# 889           1           0           0
# 890           0           1           0
#
# [889 rows x 11 columns]

# %%
## fixing test set
df_test = df_test.drop(['Ticket', 'Fare', 'Cabin', 'Name'], axis = 'columns')

# %%
df_test['Age'].fillna(df_test['Age'].median(), inplace=True)
# Out:
# /var/folders/z_/c14cvny95r120t__g05k8_zh0000gn/T/ipykernel_786/3103559757.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test['Age'].fillna(df_test['Age'].median(), inplace=True)

# %%
df_test['Age_bin'] = pd.qcut(df_test['Age'], q=4, labels=False)
df_test = df_test.drop(['Age'], axis = 1)

# %%
categorical_binary = ["Sex"]
categorical_dummy = ["Embarked"]

# %%
label = LabelEncoder()
for feature in categorical_binary:
    df_test[feature] = label.fit_transform(df_test[feature])
df_test
# Out:
#      PassengerId  Pclass  Sex  SibSp  Parch Embarked  Age_bin
# 0            892       3    1      0      0        Q        2
# 1            893       3    0      1      0        S        3
# 2            894       2    1      0      0        Q        3
# 3            895       3    1      0      0        S        1
# 4            896       3    0      1      1        S        0
# ..           ...     ...  ...    ...    ...      ...      ...
# 413         1305       3    1      0      0        S        1
# 414         1306       1    0      0      0        C        3
# 415         1307       3    1      0      0        S        3
# 416         1308       3    1      0      0        S        1
# 417         1309       3    1      1      1        C        1
#
# [418 rows x 7 columns]

# %%
df_test = pd.get_dummies(df_test, columns = categorical_dummy, dtype=int)
df_test
# Out:
#      PassengerId  Pclass  Sex  SibSp  Parch  Age_bin  Embarked_C  Embarked_Q  \
# 0            892       3    1      0      0        2           0           1
# 1            893       3    0      1      0        3           0           0
# 2            894       2    1      0      0        3           0           1
# 3            895       3    1      0      0        1           0           0
# 4            896       3    0      1      1        0           0           0
# ..           ...     ...  ...    ...    ...      ...         ...         ...
# 413         1305       3    1      0      0        1           0           0
# 414         1306       1    0      0      0        3           1           0
# 415         1307       3    1      0      0        3           0           0
# 416         1308       3    1      0      0        1           0           0
# 417         1309       3    1      1      1        1           1           0
#
#      Embarked_S
# 0             0
# 1             1
# 2             0
# 3             1
# 4             1
# ..          ...
# 413           1
# 414           0
# 415           1
# 416           1
# 417           0
#
# [418 rows x 9 columns]

# %% [markdown]
# # **Step 4: Model**

# %% [markdown]
# - Tree Model
#     - Decision Tree
#     - Bagging: RandomForest
#     - Boosting(GBDT): XGBoost, LightGBM
# - Linear Model
#     - Ridge
# - SVM
# - KNN
#
# Naive Bayes
#
# Logistic Regression
#
# Decision Tree
#
# K Nearest Neighbor
#
# Random Forest
#
# SUpport Vector Classifier
#
# Xtreme Gradient Boosting
#
# Soft Voting Classifier

# %% [markdown]
# ### Split

# %%
X = df_train.drop(['Survived'], axis=1)
y = df_train['Survived']

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=42)
def baseline(model_name, X_train, X_valid, y_train, y_valid):
    model = model_name
    model.fit(X_train, y_train)
    y_pred = model.predict(X_valid)
    model_score = accuracy_score(y_pred, y_valid)
    return model_score

# %%
list_of_models = {
    'xgb' : XGBClassifier(),
    'lr' : LogisticRegression(max_iter=1000),
    'rf' : RandomForestClassifier(),
    'knn' : KNeighborsClassifier(),
    'gnb' : GaussianNB(),
    'dt' : DecisionTreeClassifier(random_state=1),
    'gb' : GradientBoostingClassifier()}

report = pd.DataFrame(
    {
    'Model': ['XGBoost', 'Logistic Regression', 'Random Forest', 'KNN', 'Naive Bayes', 'Decision Tree', 'Grradient Boosting'],
    'Score': [None] * len(list_of_models),
    'Score after tuning':[None] * len(list_of_models),
    'Best params':[None] * len(list_of_models)
    }
).astype({'Score': 'float64'})                           

i = 0
for model in list_of_models.values():
    model_score = baseline(model, X_train, X_valid, y_train, y_valid)
    report.loc[i, 'Score'] = model_score
    i+=1

report
# Out:
#                  Model     Score Score after tuning Best params
# 0              XGBoost  0.790262               None        None
# 1  Logistic Regression  0.808989               None        None
# 2        Random Forest  0.794007               None        None
# 3                  KNN  0.573034               None        None
# 4          Naive Bayes  0.801498               None        None
# 5        Decision Tree  0.737828               None        None
# 6   Grradient Boosting  0.820225               None        None

# %% [markdown]
# # **Step 5: Tuning**

# %% [markdown]
# ### Utils

# %%
def tuning(model_name, param_grid, kf, grid_search_cv = False, randomized_search_cv = False):
    model = model_name

    if grid_search_cv:
        model = GridSearchCV(model, param_grid = param_grid, cv = kf, n_jobs = -1)
    elif randomized_search_cv:
        model = RandomizedSearchCV(model, param_distributions=param_grid, cv=kf, n_iter=10)

    best_model = model.fit(X_train, y_train)
        
    return best_model.best_score_, best_model.best_params_, best_model

# %% [markdown]
# ### Configuration

# %%
param_grid = {  
    "XGBoost": {
        'n_estimators': [100, 200, 300],
        'learning_rate': [0.01, 0.05, 0.1],
        'max_depth': [3, 5, 7, 9],
        'min_child_weight': [1, 3, 5]
    },
    "Logistic Regression": {
        "max_iter": [2000],
        "penalty": ["l1", "l2"],
        "C": [1e-4, 1e-3, 1e-2, 1e-1, 1, 1e1, 1e2, 1e3, 1e4],
        "solver": ["liblinear"]
    },
    "Random Forest": {
        "n_estimators": [100, 200, 300],
        "max_features": ["auto", "sqrt"],
        "max_depth": [10]
    },
    "K-Nearest Neighbors": {
        "n_neighbors": [3, 5, 10],
        "weights": ["uniform", "distance"],
        "metric": ["euclidean", "manhattan"]
    },
    "Gaussian Naive Bayes": {
        "var_smoothing": [1, 0.1, 0.01, 0.001, 0.0001, 1e-5, 1e-6, 1e-7, 1e-8, 1e-9]
    },
    "Decision Tree": {
        "max_depth": [None, 10, 20, 30],
        "min_samples_split": [2, 10, 20],
        "min_samples_leaf": [1, 5, 10]
    },
    "Gradient Boosting": {
    'n_estimators': (50, 200), 
    'learning_rate': (0.01, 0.2), 
    'max_depth': (3, 10),  
    'min_samples_split': (2, 10),  
    'min_samples_leaf': (1, 10), 
    'max_features': ('sqrt', 'log2', None),  
    'subsample': (0.5, 1.0) 
    }
    
}

# %% [markdown]
# ### RUN!!

# %%
p = ["XGBoost",
            "Logistic Regression",
            "Random Forest",
            "K-Nearest Neighbors",
            "Gaussian Naive Bayes",
            "Decision Tree",
            "Gradient Boosting"
]

kf = KFold(n_splits=5, shuffle=True, random_state=42)

i = 0
model_list = []
for model in tqdm(list_of_models.values()):
    best_score, best_params, best_model = tuning(model, param_grid[p[i]], kf, randomized_search_cv = True)
    report.loc[i, 'Score after tuning'] = best_score
    report.loc[i, 'Best params'] = str(best_params)
    model_list.append(best_model)
    i+=1

report
# Out:
# 100%|██████████| 7/7 [00:28<00:00,  4.09s/it]
#                  Model     Score Score after tuning  \
# 0              XGBoost  0.790262           0.807032
# 1  Logistic Regression  0.808989           0.799045
# 2        Random Forest  0.794007           0.784439
# 3                  KNN  0.573034           0.636684
# 4          Naive Bayes  0.801498           0.797303
# 5        Decision Tree  0.737828           0.786142
# 6   Grradient Boosting  0.820225           0.808594
#
#                                          Best params
# 0  {'n_estimators': 100, 'min_child_weight': 1, '...
# 1  {'solver': 'liblinear', 'penalty': 'l2', 'max_...
# 2  {'n_estimators': 200, 'max_features': 'sqrt', ...
# 3  {'weights': 'distance', 'n_neighbors': 5, 'met...
# 4                           {'var_smoothing': 1e-06}
# 5  {'min_samples_split': 10, 'min_samples_leaf': ...
# 6  {'subsample': 0.5, 'n_estimators': 200, 'min_s...

# %% [markdown]
# ### Optional Details

# %% [markdown]
# ##### 1. Tuning for **Logistic Regression** model

# %%
# lr = LogisticRegression()


# tuning(lr, param_grid_lr, kf, grid_search_cv = True)

# %% [markdown]
# ##### 2. Tuning for **Random Forest** model

# %%
# rf = RandomForestClassifier()
# param_grid_rf = {
#     'n_estimators': [100, 200, 300],
#     'max_features': ['auto', 'sqrt'],
#     'max_depth': [10]
# }
# tuning(rf, param_grid_rf, kf, grid_search_cv = True)

# %% [markdown]
# ##### 3. Tuning for **Naive Bayes** model

# %%
# gnb = GaussianNB()
# param_grid_gnb = {
#     'var_smoothing': np.logspace(0, -9, num=100)
# }

# tuning(gnb, param_grid_gnb, kf, grid_search_cv = True)

# %% [markdown]
# ##### 4. Tuning for **Decision Tree** model

# %%
# dt = DecisionTreeClassifier()
# param_grid_dt = {
#     'max_depth': [None, 10, 20, 30],
#     'min_samples_split': [2, 10, 20],
#     'min_samples_leaf': [1, 5, 10]
# }

# tuning(dt, param_grid_dt, kf, grid_search_cv =True)

# %% [markdown]
# ##### 5. Tuning for **K Nearest Neighbor** model

# %%
# knn = KNeighborsClassifier()
# param_grid_knn = {
#     'n_neighbors': [3, 5, 10],
#     'weights': ['uniform', 'distance'],
#     'metric': ['euclidean', 'manhattan']
# }

# tuning(knn, param_grid_knn, kf, grid_search_cv =True)

# %% [markdown]
# ##### 6. Tuning for **XGB** model(Extreme Gradient Boosting)

# %%
# xgb = XGBClassifier()
# param_grid_xgb = {
#     'n_estimators': [100, 200],
#     'learning_rate': [0.01, 0.1, 0.2],
#     'max_depth': [3, 5, 7]
# }

# best_score,best_params = tuning(xgb, param_grid_xgb, kf, randomized_search_cv=True)

# %% [markdown]
# # **Step 6: Inference**

# %%
best_index = 0 # observe by yourself

y_pred = model_list[best_index].predict(df_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[450], line 3
#       1 best_index = 0 # observe by yourself
# ----> 3 y_pred = model_list[best_index].predict(df_test)
#
# File ~/anaconda3/envs/datascience/lib/python3.9/site-packages/sklearn/model_selection/_search.py:546, in BaseSearchCV.predict(self, X)
#     528 """Call predict on the estimator with the best found parameters.
#     529
#     530 Only available if ``refit=True`` and the underlying estimator supports
#    (...)
#     543     the best found parameters.
#     544 """
#     545 check_is_fitted(self)
# --> 546 return self.best_estimator_.predict(X)
#
# File ~/anaconda3/envs/datascience/lib/python3.9/site-packages/xgboost/sklearn.py:1553, in XGBClassifier.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1544 def predict(
#    1545     self,
#    1546     X: ArrayLike,
#    (...)
#    1550     iteration_range: Optional[Tuple[int, int]] = None,
#    1551 ) -> ArrayLike:
#    1552     with config_context(verbosity=self.verbosity):
# -> 1553         class_probs = super().predict(
#    1554             X=X,
#    1555             output_margin=output_margin,
#    1556             validate_features=validate_features,
#    1557             base_margin=base_margin,
#    1558             iteration_range=iteration_range,
#    1559         )
#    1560         if output_margin:
#    1561             # If output_margin is active, simply return the scores
#    1562             return class_probs
#
# File ~/anaconda3/envs/datascience/lib/python3.9/site-packages/xgboost/sklearn.py:1168, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1166 if self._can_use_inplace_predict():
#    1167     try:
# -> 1168         predts = self.get_booster().inplace_predict(
#    1169             data=X,
#    1170             iteration_range=iteration_range,
#    1171             predict_type="margin" if output_margin else "value",
#    1172             missing=self.missing,
#    1173             base_margin=base_margin,
#    1174             validate_features=validate_features,
#    1175         )
#    1176         if _is_cupy_array(predts):
#    1177             import cupy  # pylint: disable=import-error
#
# File ~/anaconda3/envs/datascience/lib/python3.9/site-packages/xgboost/core.py:2418, in Booster.inplace_predict(self, data, iteration_range, predict_type, missing, validate_features, base_margin, strict_shape)
#    2416     data, fns, _ = _transform_pandas_df(data, enable_categorical)
#    2417     if validate_features:
# -> 2418         self._validate_features(fns)
#    2419 if _is_list(data) or _is_tuple(data):
#    2420     data = np.array(data)
#
# File ~/anaconda3/envs/datascience/lib/python3.9/site-packages/xgboost/core.py:2970, in Booster._validate_features(self, feature_names)
#    2964 if my_missing:
#    2965     msg += (
#    2966         "\ntraining data did not have the following fields: "
#    2967         + ", ".join(str(s) for s in my_missing)
#    2968     )
# -> 2970 raise ValueError(msg.format(self.feature_names, feature_names))
#
# ValueError: feature_names mismatch: ['PassengerId', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Age_bin', 'Title', 'Embarked_C', 'Embarked_Q', 'Embarked_S'] ['PassengerId', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Age_bin', 'Embarked_C', 'Embarked_Q', 'Embarked_S']
# expected Title in input data

# %%
y_pred # Your prediction

# %%
pd.Series(y_pred)

# %% [markdown]
# ## **Step 7: Submit to Kaggle**

# %%
df = pd.read_csv('gender_submission.csv')

# %%
df["Survived"] = pd.Series(y_pred)

# %%
# Check
df.iloc[6,1]

# %%
df.to_csv("yiming_submission.csv", index=False)
